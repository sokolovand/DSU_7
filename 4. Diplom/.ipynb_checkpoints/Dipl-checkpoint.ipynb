# %%
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv('HR.csv')

# %%
data.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# ...

# %%
data.mode()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                 0.1             0.55             4.0                   135
# 1                 NaN              NaN             NaN                   156
#
#    time_spend_company  Work_accident  left  promotion_last_5years department  \
# 0                 3.0            0.0   0.0                    0.0      sales
# 1                 NaN            NaN   NaN                    NaN        NaN
#
#   salary
# 0    low
# 1    NaN

# %%
data_1 = data[['satisfaction_level', 'last_evaluation', 'number_project', 'average_montly_hours', 'time_spend_company', 'Work_accident', ]]

# %%
sns.pairplot(data_1)

# %%
data_1.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_f6b347e0_fe73_11eb_9b0e_efa7ae70744erow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f6b347e0_fe73_11eb_9b0e_efa7ae70744erow0_col1 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_f6b347e0_fe73_11eb_9b0e_efa7ae70744erow0_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f6b347e0_fe73_11eb_9b0e_efa7ae70744erow0_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f6b347e0_fe73_11eb_9b0e_efa7ae70744erow0_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f6b347e0_fe73_11eb_9b0e_efa7ae70744erow0_col5 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_f6b347e0_fe73_11eb_9b0e_efa7ae70744erow1_col0 {
#             background-color:  #81a4fb;
#             color:  #000000;
# ...

# %%
people = data.groupby(by='department').count()
people.iloc[:,0].reset_index()
# Out:
#     department  satisfaction_level
# 0           IT                1227
# 1        RandD                 787
# 2   accounting                 767
# 3           hr                 739
# 4   management                 630
# 5    marketing                 858
# 6  product_mng                 902
# 7        sales                4140
# 8      support                2229
# 9    technical                2720

# %%
from sklearn.model_selection import train_test_split
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
data.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# ...

# %%
x = data.iloc[:, [0,1, 2, 3, 4, 5, 7]]
y = data.iloc[:, 6]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.67, random_state=100)

# %%
lda = LinearDiscriminantAnalysis()
lda.fit(x_train, y_train)
y_predict = lda.predict(x_test)

print(f'Точность модели составляет: {lda.score(x_test, y_test)}')

compair = pd.DataFrame({
    'y_test': y_test,
    'y_predict': y_predict
})
# Out:
# Точность модели составляет: 0.7608080808080808

# %%
from sklearn.metrics import accuracy_score

# %%
# Метрика точности

accuracy_score(y_test, y_predict)
# Out:
# 0.7608080808080808

# %%
data.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# ...

# %%
print(len(y_test))
print(len(y_predict))
# Out:
# 4950
# 4950

# %%
# В 75% случаев модель угадывает правильный ответ
